# %% [markdown]
# ## Extractable

# %%
import extractable as ex

# %%
input_file = "../data/NATS-Nursery-Ltd-Catalogue-2019_NativePerennials.pdf"
output_dir = "../data/NativePerennials/"

ex.extract(input_file=input_file, output_dir=output_dir, output_filetype=ex.Filetype.CSV)

# %% [markdown]
# ## PyMuPDF
#
# Reference: https://github.com/pymupdf/PyMuPDF-Utilities/blob/master/table-analysis/join_tables.ipynb

# %%
import pandas as pd
import os
import fitz
if not hasattr(fitz.Page, "find_tables"):
    raise RuntimeError("This PyMuPDF version does not support the table feature")

from config import columns, config, corrections, mappings

pd.set_option("display.expand_frame_repr", False)
pd.set_option("display.max_rows", 10)
pd.set_option("max_colwidth", 15)

# %%
input_file_prefix = config.PDF_PREFIX
output_dir = config.CATALOG_DIR
output_file = config.CATALOG_FILE_NATS
# output_file_modified = os.path.join(output_dir, "catalogue_nats_merged_modified.csv")


def replace_acronyms(column, mapping):
    for acronym, full_text in mapping.items():
        column = column.str.replace(r'\b' + acronym + r'\b', full_text, regex=True)
    return column


def extract_category_data(category, category_name):
    input_file = f'{input_file_prefix}_{category}.pdf'
    doc = fitz.open(input_file)
    
    print(f'=== {category} ===')
    df_fragments = []  # list of DataFrames per table fragment
    for page in doc:  # iterate over the pages
        tabs = page.find_tables()
        if len(tabs.tables) == []:
            break
        tab = tabs[0]  # the 1st table
        df_tmp = tab.to_pandas()
        df_fragments.append(df_tmp)  # append this DataFrame
        print(df_tmp.shape)
    
    df = pd.concat(df_fragments)
    df['CATEGORY'] = category_name
    
    df.replace({r"‘|’": "'", r"“|”": '"', "\n": " "}, regex=True, inplace=True)

    df['SUN'] = replace_acronyms(df['SUN'], mappings.SUN_MAPPING)
    df['SOIL'] = replace_acronyms(df['SOIL'], mappings.SOIL_MAPPING)
    df['HABITAT'] = replace_acronyms(df['HABITAT'], mappings.HABITAT_MAPPING)
    try:
        df['SPEC SIZES'] = replace_acronyms(df['SPEC SIZES'], mappings.SIZE_MAPPING)
    except KeyError:
        pass

    return df

# %%
os.makedirs(output_dir, exist_ok=True)

for category, category_name in mappings.CATEGORIES.items():
    df = extract_category_data(category, category_name)
    
    output_file_category = os.path.join(output_dir, f'{category}.csv')
    df.to_csv(output_file_category, index=False)
    print(df, end='\n\n')
    print(f'File saved: {output_file_category}', end='\n\n')
# Out:
# === NativePerennials ===
# (19, 6)
# (25, 6)
# (25, 6)
# (25, 6)
# (3, 6)
#              LATIN          COMMON             SUN            SOIL         HABITAT      SPEC SIZES        CATEGORY
# 0   Achillea mi...          Yarrow  Sun/Partial...  Moist/Dry, ...  Disturbed S...  Plug, Conta...  Native Pere...
# 1   Achlys trip...    Vanilla Leaf  Shade/Parti...    Moist, Humus  Shade Fores...       Container  Native Pere...
# 2   Allium acum...  Hooker's Onion             Sun  Well Draine...  Grassland, ...  Plug, Conta...  Native Pere...
# 3   Allium cernuum   Nodding Onion  Sun/Partial...  Well Draine...  Shoreline, ...  Plug, Conta...  Native Pere...
# 4   Allium scho...          Chives  Sun/Partial...    Well Drained  Disturbed S...  Plug, Conta...  Native Pere...
# ..             ...             ...             ...             ...             ...             ...             ...
# 23  Vancouveria...  Inside-out ...   Partial Shade  Moist/Dry, ...    Shade Forest  Plug, Conta...  Native Pere...
# 24    Viola adunca  Early Blue ...  Sun/Partial...           Moist  Open Forest...  Plug, Conta...  Native Pere...
# 0   Viola praem...  Yellow Montane             Sun             Dry  Grassland, ...         Inquire  Native Pere...
# 1   Viola sempe...  Trailing Ye...  Shade/Parti...           Moist    Shade Forest       Container  Native Pere...
# 2   Xerophyllum...       Beargrass  Sun/Partial...  Moist, Well...  Grassland, ...         Inquire  Native Pere...
#
# [97 rows x 7 columns]
#
# File saved: ./catalogues/NativePerennials.csv
#
# === NativeGroundcovers ===
# (14, 6)
#              LATIN          COMMON             SUN            SOIL         HABITAT      SPEC SIZES        CATEGORY
# 0   Arctostaphy...    Kinnikinnick  Sun/Partial...  Moist/Dry, ...  Shoreline, ...  Plug, Conta...  Native Grou...
# 1   Asarum caud...     Wild Ginger  Partial Sha...    Moist, Humus    Shade Forest       Container  Native Grou...
# 2   Cornus cana...      Bunchberry  Shade/Parti...  Moist, Acid...  Shade Fores...  Plug, Conta...  Native Grou...
# 3   Dryas drumm...  Yellow Moun...  Sun/Partial...  Moist/Dry, ...  Riparian, M...            Plug  Native Grou...
# 4   Dryas octop...  White Mount...             Sun  Well Draine...  Grassland, ...         Inquire  Native Grou...
# ..             ...             ...             ...             ...             ...             ...             ...
# 9   Oxalis oregana  Redwood Sorrel           Shade    Moist, Humus    Shade Forest  Plug, Conta...  Native Grou...
# 10  Rhodiola rosea        Roseroot  Sun/Partial...  Moist/Dry, ...  Disturbed S...  Plug, Conta...  Native Grou...
# 11  Sedum diver...  Spreading S...             Sun  Moist/Dry, ...  Disturbed S...  Un-Rooted C...  Native Grou...
# 12  Sedum oreganum  Oregon Ston...             Sun  Moist/Dry, ...  Shoreline, ...  Un-Rooted C...  Native Grou...
# 13  Sedum spath...  Broad-leave...             Sun  Moist/Dry, ...  Shoreline, ...            Plug  Native Grou...
#
# [14 rows x 7 columns]
#
# File saved: ./catalogues/NativeGroundcovers.csv
#
# === NativeShrubs ===
# (20, 6)
# (25, 6)
# (25, 6)
#              LATIN          COMMON             SUN            SOIL         HABITAT      SPEC SIZES       CATEGORY
# 0   Acer circin...      Vine Maple  Sun/Partial...  Moist, Well...  Shade Fores...  Plug, Conta...  Native Shrubs
# 1     Acer glabrum   Douglas Maple  Sun/Partial...  Moist/Dry, ...  Grassland, ...  Plug, Conta...  Native Shrubs
# 2   Alnus virid...     Sitka Alder  Sun/Partial...       Moist/Wet  Riparian, S...  Plug, Conta...  Native Shrubs
# 3   Amelanchier...  Saskatoon S...  Sun/Partial...       Moist/Dry  Grassland, ...  Plug, Conta...  Native Shrubs
# 4   Andromeda p...    Bog Rosemary  Sun/Partial...  Moist/Wet, ...  Bog, Montan...  Plug, Conta...  Native Shrubs
# ..             ...             ...             ...             ...             ...             ...            ...
# 20  Vaccinium p...  Red Huckleb...  Shade/Parti...  Moist,Humus...    Shade Forest  Plug, Conta...  Native Shrubs
# 21  Vaccinium s...     Grouseberry   Partial Shade  Dry/Moist,W...  Montane/Alp...         Inquire  Native Shrubs
# 22  Vaccinium u...   Bog Blueberry  Sun/Partial...  Wet/Moist,W...  Bog, Montan...  Plug, Conta...  Native Shrubs
# 23  Vaccinium v...     Lingonberry  Sun/Partial...  Wet/Moist/D...  Open Forest...  Plug, Conta...  Native Shrubs
# 24  Viburnum edule  Highbush Cr...  Sun/Partial...       Moist/Wet  Shade Fores...         Inquire  Native Shrubs
#
# [70 rows x 7 columns]
#
# File saved: ./catalogues/NativeShrubs.csv
#
# === NativeTrees ===
# (28, 6)
#              LATIN          COMMON             SUN            SOIL         HABITAT      SPEC SIZES      CATEGORY
# 0    Abies grandis       Grand Fir  Sun/Partial...  Moist, Well...  Open Forest...  Plug, Conta...  Native Trees
# 1   Acer macrop...  Big-leaf Maple  Sun/Partial...  Moist/Dry, ...  Shade Fores...  Plug, Conta...  Native Trees
# 2      Alnus rubra       Red Alder  Sun/Partial...   Dry/Moist/Wet  Open Forest...  Plug, Conta...  Native Trees
# 3   Arbutus men...  Arbutus (Pa...             Sun  Dry/Rocky, ...  Shoreline, ...  Plug, Conta...  Native Trees
# 4   Betula papy...     Paper Birch  Sun/Partial...  Moist/Wet, ...  Open Forest...  Plug, Conta...  Native Trees
# ..             ...             ...             ...             ...             ...             ...           ...
# 23  Quercus gar...       Garry Oak             Sun  Moist/Dry, ...  Grassland, ...  Plug, Conta...  Native Trees
# 24  Taxus brevi...     Pacific Yew  Shade/Parti...           Moist  Shade Fores...         Inquire  Native Trees
# 25   Thuja plicata  Western Red...  Sun/Partial...       Moist/Wet  Shade Fores...  Plug, Conta...  Native Trees
# 26  Tsuga heter...  Western Hem...       Sun/Shade    Moist, Humus  Shade Fores...  Plug, Conta...  Native Trees
# 27  Tsuga merte...  Mountain He...  Sun/Partial...  Moist/Wet, ...  Montane/Alp...       Container  Native Trees
#
# [28 rows x 7 columns]
#
# File saved: ./catalogues/NativeTrees.csv
#
# === NativeWetlandPlants ===
# (26, 6)
# (17, 6)
#              LATIN          COMMON             SUN            SOIL         HABITAT      SPEC SIZES        CATEGORY
# 0   Carex aquat...     Sitka Sedge             Sun             Wet         Wetland  Plug, Conta...  Native Wetl...
# 1     Carex bebbii  Bebb's Oval...             Sun             Wet         Wetland         Inquire  Native Wetl...
# 2      Carex densa     Dense sedge  Sun/Partial...       Moist/Wet  Wetland, Gr...  Plug, Conta...  Native Wetl...
# 3   Carex deweyana   Dewey's Sedge  Partial Sha...       Dry/Moist  Bio-filtrat...            Plug  Native Wetl...
# 4   Carex exsic...  Inflated Sedge             Sun       Wet/Humus         Wetland         Inquire  Native Wetl...
# ..             ...             ...             ...             ...             ...             ...             ...
# 12  Scirpus lac...  Soft-stemme...             Sun             Wet  Wetland, Sh...  Plug, Conta...  Native Wetl...
# 13  Scirpus (Sc...  Sea Coast B...  Sun/Partial...             Wet  Shoreline, ...            Plug  Native Wetl...
# 14  Scirpus mic...  Small Flowe...  Sun/Partial...             Wet  Wetland, Gr...  Plug, Conta...  Native Wetl...
# 15  Triglochin ...  Seaside Arr...             Sun  Wet, Alkali...  Shoreline, ...         Inquire  Native Wetl...
# 16  Typha latif...         Cattail  Sun/Partial...             Wet         Wetland  Plug, Conta...  Native Wetl...
#
# [43 rows x 7 columns]
#
# File saved: ./catalogues/NativeWetlandPlants.csv
#
# === Grasses-Associates ===
# (6, 6)
# (27, 6)
#              LATIN          COMMON             SUN            SOIL         HABITA
# %%
dfs = []
for category in mappings.CATEGORIES:
    df = pd.read_csv(os.path.join(output_dir, f'{category}.csv'))
    
    # Rename 'SPEC SIZES' to 'SIZES'
    if 'SPEC SIZES' in df.columns:
        df.rename(columns={'SPEC SIZES': 'SIZES'}, inplace=True)
    
    dfs.append(df)

df_merged = pd.concat(dfs, ignore_index=True)
col_names_original = df_merged.columns

# Create a new column to store original values, set to '' for non-changed values
df_merged['LATIN_0'] = df_merged['LATIN'].where(df_merged['LATIN'].isin(corrections.LATIN_REPLACE_NATS.keys()), '')
df_merged['COMMON_0'] = df_merged['COMMON'].where(df_merged['COMMON'].isin(corrections.COMMON_REPLACE_NATS.keys()), '')
# Correct names
df_merged['LATIN'] = df_merged['LATIN'].replace(corrections.LATIN_REPLACE_NATS)
df_merged['COMMON'] = df_merged['COMMON'].replace(corrections.COMMON_REPLACE_NATS)

df_merged.sort_values(by='LATIN', inplace=True)
df_merged = df_merged[columns.COL_NAMES_NATS]

df_merged.to_csv(output_file, index=False)
print(df_merged.shape, end='\n\n')
print(f'File saved: {output_file}', end='\n\n')

# for col in columns.COL_NAMES_ALL:
#     if col not in col_names_original:
#         df_merged[col] = '' 

# df_merged = df_merged[columns.COL_NAMES_ALL]

# df_merged.to_csv(output_file_modified, index=False)
# print(df_merged)
# print(f'File saved: {output_file_modified}')
# Out:
# (359, 7)
#
# File saved: ./catalogues/catalogue_merged_original.csv
#
#     IN_STOCK           LATIN          COMMON SQUAMISH HALKOMELEM FAMILY        CATEGORY KEYWORDS MAX_HEIGHT             SUN            SOIL         HABITAT           SIZES GROWING_EASE USE_VALUE ATTRACTS URL IMAGE DESCRIPTION
# 0             Achillea mi...          Yarrow                             Native Pere...                      Sun/Partial...  Moist/Dry, ...  Disturbed S...  Plug, Conta...
# 1             Achlys trip...    Vanilla Leaf                             Native Pere...                      Shade/Parti...    Moist, Humus  Shade Fores...       Container
# 2             Allium acum...  Hooker's Onion                             Native Pere...                                 Sun  Well Draine...  Grassland, ...  Plug, Conta...
# 3             Allium cernuum   Nodding Onion                             Native Pere...                      Sun/Partial...  Well Draine...  Shoreline, ...  Plug, Conta...
# 4             Allium scho...          Chives                             Native Pere...                      Sun/Partial...    Well Drained  Disturbed S...  Plug, Conta...
# ..       ...             ...             ...      ...        ...    ...             ...      ...        ...             ...             ...             ...             ...          ...       ...      ...  ..   ...         ...
# 354           Cornus nutt...  Eddie's Whi...                             Miscellaneo...                      Sun/Partial...    Well Drained     Open Forest       Container
# 355           Metasequoia...    Dawn Redwood                             Miscellaneo...                                 Sun  Humus/Moist...  Shade Fores...         Inquire
# 356              Rosa rugosa  Saltspray Rose                             Miscellaneo...                                 Sun    Well Drained       Shoreline         Inquire
# 357           Sequoiadend...   Giant Sequoia                             Miscellaneo...                                 Sun  Moist/Well ...  Shade Fores...  Container, B&B
# 358           Sequoiadend...  Weeping Gia...                             Miscellaneo...                                 Sun  Moist/Well ...     Open Forest  Container, B&B
#
# [359 rows x 19 columns]
# File saved: ./catalogues/catalogue_merged.csv
