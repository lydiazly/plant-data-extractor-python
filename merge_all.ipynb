# %%
import pandas as pd
import os
from config import columns, config

# %%
input_file_nats = config.CATALOG_FILE_NATS
input_file_shop = config.CATALOG_FILE_SHOP
output_file = os.path.join(config.CATALOG_DIR, "catalogue_all_merged.csv")

df_nats = pd.read_csv(input_file_nats)
df_shop = pd.read_csv(input_file_shop)


def add_keyword(df, keyword):
    mask = df['CATEGORY'].str.contains(keyword) & ~df['KEYWORDS'].str.contains(keyword)
    df.loc[mask, 'KEYWORDS'] = df.loc[mask, 'KEYWORDS'].apply(lambda x: keyword + (', ' + x if x else ''))
    return df

# %%
list(df_nats.columns)
# Out:
# ['LATIN', 'LATIN_0', 'COMMON', 'SUN', 'SOIL', 'HABITAT', 'SIZES', 'CATEGORY']

# %%
list(df_shop.columns)
# Out:
# ['IN_STOCK',
#  'LATIN',
#  'LATIN_0',
#  'COMMON',
#  'COMMON_0',
#  'SQUAMISH',
#  'HALKOMELEM',
#  'KEYWORDS',
#  'IMAGE',
#  'LINK',
#  'DESCRIPTION']

# %%
df_merged = pd.merge(df_nats, df_shop, on='LATIN', how='outer', suffixes=('', '_shop')).fillna('')
df_merged.sort_values(by='LATIN', inplace=True)
df_merged.reset_index(drop=True, inplace=True)
col_names_original = df_merged.columns
print(list(col_names_original))

# Correct 'Perennial/Annual' in 'KEYWORDS'
if corrections.PERENNIALS:
    mask = df_merged['LATIN'].isin(corrections.PERENNIALS)
    df_merged.loc[mask, 'KEYWORDS'] = df_merged.loc[mask, 'KEYWORDS'].str.replace('Perennial/Annual', 'Perennial')
if corrections.ANNUALS:
    mask = df_merged['LATIN'].isin(corrections.ANNUALS)
    df_merged.loc[mask, 'KEYWORDS'] = df_merged.loc[mask, 'KEYWORDS'].str.replace('Perennial/Annual', 'Annual')

# Prepend keywords
for keyword in ['Perennial', 'Native Trees', 'Shrubs', 'Groundcover']:
    df_merged = add_keyword(df_merged, keyword)

for col in columns.COL_NAMES_ALL:
    if col not in col_names_original:
        df_merged[col] = ""

df_merged = df_merged[columns.COL_NAMES_ALL]

df_merged.to_csv(output_file, index=False)
print(f"File saved: {output_file}")

df_merged
# Out:
# ['LATIN', 'LATIN_0', 'COMMON', 'SUN', 'SOIL', 'HABITAT', 'SIZES', 'CATEGORY', 'IN_STOCK', 'LATIN_0_shop', 'COMMON_shop', 'COMMON_0', 'SQUAMISH', 'HALKOMELEM', 'KEYWORDS', 'IMAGE', 'LINK', 'DESCRIPTION']
# File saved: ./catalogues/catalogue_all_merged.csv
#     IN_STOCK                        LATIN                  COMMON SQUAMISH  \
# 0             Abies balsamea phanerolepis              Caanan Fir
# 1                          Abies concolor               White Fir
# 2                           Abies fraseri              Fraser Fir
# 3                           Abies grandis               Grand Fir
# 4                           Abies grandis               Grand Fir
# ..       ...                          ...                     ...      ...
# 355                        Viburnum edule      Highbush Cranberry
# 356                          Viola adunca       Early Blue Violet
# 357                       Viola praemorsa          Yellow Montane
# 358                    Viola sempervirens  Trailing Yellow Violet
# 359                     Xerophyllum tenax               Beargrass
#
#     HALKOMELEM FAMILY                  CATEGORY KEYWORDS MAX_HEIGHT  \
# 0                      Christmas Tree Seedlings
# 1                      Christmas Tree Seedlings
# 2                      Christmas Tree Seedlings
# 3                                  Native Trees
# 4                      Christmas Tree Seedlings
# ..         ...    ...                       ...      ...        ...
# 355                               Native Shrubs
# 356                           Native Perennials
# 357                           Native Perennials
# 358                           Native Perennials
# 359                           Native Perennials
#
#                      SUN                     SOIL  \
# 0                    Sun       Moist/Well Drained
# 1      Sun/Partial Shade  Dry/Moist, Well Drained
# 2                    Sun       Moist/Well Drained
# 3      Sun/Partial Shade      Moist, Well Drained
# 4      Sun/Partial Shade      Moist, Well Drained
# ..                   ...                      ...
# 355    Sun/Partial Shade                Moist/Wet
# 356    Sun/Partial Shade                    Moist
# 357                  Sun                      Dry
# 358  Shade/Partial Shade                    Moist
# 359    Sun/Partial Shade      Moist, Well Drained
#
#                                                HABITAT  \
# 0                         Shade Forest, Montane/Alpine
# 1                         Shade Forest, Montane/Alpine
# 2                         Shade Forest, Montane/Alpine
# 3                            Open Forest, Shade Forest
# 4                            Open Forest, Shade Forest
# ..                                                 ...
# 355         Shade Forest, Riparian, Wetland, Grassland
# 356  Open Forest, Forest Edge, Grassland, Disturbed...
# 357                             Grassland, Open Forest
# 358                                       Shade Forest
# 359  Grassland, Open Forest, Forest Edge, Montane/A...
#
#                            SIZES GROWING_EASE USE_VALUE ATTRACTS IMAGE LINK  \
# 0                     60P (515A)
# 1                        Inquire
# 2    77P (412A/415D), 60P (515A)
# 3                Plug, Container
# 4                77P (412A/415D)
# ..                           ...          ...       ...      ...   ...  ...
# 355                      Inquire
# 356              Plug, Container
# 357                      Inquire
# 358                    Container
# 359                      Inquire
#
#     DESCRIPTION
# 0
# 1
# 2
# 3
# 4
# ..          ...
# 355
# 356
# 357
# 358
# 359
#
# [360 rows x 19 columns]
